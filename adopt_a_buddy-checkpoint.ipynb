# %% [markdown]
# # Adopt a Buddy
# # Hackerearth competition

# %%
import pandas as pd
import numpy as np
import xgboost as xgb

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from datetime import date
# Out:
# C:\Users\user\Anaconda3\envs\HC#7062_stage1\lib\site-packages\distributed\utils.py:134: RuntimeWarning: Couldn't detect a suitable IP address for reaching '8.8.8.8', defaulting to '127.0.0.1': [WinError 10065] A socket operation was attempted to an unreachable host
#   % (host, default, e), RuntimeWarning)

# %%
dataset = pd.read_csv('./a01c26dcd27711ea/Dataset/train.csv')
dataset.sort_values('breed_category')
# Out:
#            pet_id           issue_date         listing_date  condition  \
# 0      ANSL_69903  2016-07-10 00:00:00  2016-09-21 16:25:00        2.0
# 14615  ANSL_56232  2017-12-09 00:00:00  2018-03-09 14:57:00        1.0
# 7444   ANSL_58335  2013-11-27 00:00:00  2016-12-19 11:40:00        2.0
# 14614  ANSL_67807  2011-12-14 00:00:00  2017-01-15 16:33:00        1.0
# 7446   ANSL_68616  2015-11-30 00:00:00  2016-11-21 17:49:00        1.0
# 7447   ANSL_61696  2014-03-20 00:00:00  2018-11-12 18:37:00        1.0
# 7450   ANSL_55314  2016-05-17 00:00:00  2018-06-14 17:38:00        1.0
# 7452   ANSL_72228  2013-08-17 00:00:00  2016-09-17 11:39:00        1.0
# 14616  ANSL_53663  2016-11-16 00:00:00  2017-02-15 13:54:00        2.0
# 7454   ANSL_59197  2014-01-07 00:00:00  2019-03-19 16:41:00        1.0
# 14608  ANSL_68552  2017-07-13 00:00:00  2017-11-03 09:00:00        2.0
# 14607  ANSL_53373  2016-12-14 00:00:00  2018-07-08 18:15:00        1.0
# ...

# %%
'''
Traning Dataset discription:
in_features: 6
no_samples: 18834
out_features: 2 // predict

'''

# %%
# Extact input features as a np array
in_features = ['issue_date','listing_date','condition', 'color_type', 'length(m)', 'height(cm)','X1','X2']
x = np.array(dataset[in_features])
print(x)

x[0,0]
# Out:
# [['2016-07-10 00:00:00' '2016-09-21 16:25:00' 2.0 ... 7.78 13 9]
#  ['2013-11-21 00:00:00' '2018-12-27 17:47:00' 1.0 ... 14.19 13 9]
#  ['2014-09-28 00:00:00' '2016-10-19 08:24:00' nan ... 40.9 15 4]
#  ...
#  ['2010-07-21 00:00:00' '2018-08-22 14:27:00' 0.0 ... 28.13 13 9]
#  ['2017-05-12 00:00:00' '2018-02-08 14:05:00' 0.0 ... 44.82 13 9]
#  ['2011-12-13 00:00:00' '2018-10-26 14:18:00' 0.0 ... 37.4 0 1]]
# '2016-07-10 00:00:00'

# %%
out_features = ['breed_category', 'pet_category']
y = np.array(dataset[out_features])
y
# Out:
# array([[0., 1.],
#        [0., 2.],
#        [2., 4.],
#        ...,
#        [1., 1.],
#        [1., 2.],
#        [1., 2.]])

# %%
pet_category = {'0':0,'1':0,'2':0,'3':0,'4':0}
breed_category = {'0':0,'1':0,'2':0}

for f in range(0,len(dataset)):
    if (dataset['pet_category'][f] == 0):
        pet_category['0'] +=1
    if (dataset['pet_category'][f] == 1):
        pet_category['1'] +=1
    if (dataset['pet_category'][f] == 2):
        pet_category['2'] +=1
    if (dataset['pet_category'][f] == 3):
        pet_category['3'] +=1
    if (dataset['pet_category'][f] == 4):
        pet_category['4'] +=1
        
#It shows us distribution of each fruit in given dataset
#we printed no of images that a single type of fruit have in given dataset
print(' 0 : ',pet_category['0'],' 1 : ', pet_category['1'], '2 : ',pet_category['2'],
      ' 3 :',pet_category['3'],' 4 : ',pet_category['4'])
# Out:
#  0 :  88  1 :  7184 2 :  10621  3 : 0  4 :  941
